# %%
import os
import cv2
import numpy as np

# %%
def extract_color_histogram(patch, bins=8):
    hist_features = []
    for i in range(3):
        channel = patch[:,:,i]
        hist, _ = np.histogram(channel,bins=bins, range=(0,256))
        hist =  hist.astype("float") / (patch.shape[0]*patch.shape[1])
        hist_features.extend(hist)
    return np.array(hist_features)

# %%
def extract_greyscale_histogram(patch, bins=8):
    hist_features = []
    channel = patch[:,:]
    hist, _ = np.histogram(channel,bins=bins, range=(0,256))
    hist =  hist.astype("float") / (patch.shape[0]*patch.shape[1])
    hist_features.extend(hist)
    return np.array(hist_features)

# %%
def pad_image_to_multiple(img, patch_size=32, is_color=False):
    if is_color:
        h, w, c = img.shape
        new_img = np.zeros((
            ((h + patch_size - 1) // patch_size) * patch_size,
            ((w + patch_size - 1) // patch_size) * patch_size,
            3
        ), dtype=img.dtype)
        new_img[:h, :w, :] = img
    else:
        h, w = img.shape
        new_img = np.zeros((
            ((h + patch_size - 1) // patch_size) * patch_size,
            ((w + patch_size - 1) // patch_size) * patch_size
        ), dtype=img.dtype)
        new_img[:h, :w] = img
    return new_img

# %%
def process_image(image_path, patch_size=32):
    img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    if img is None:
        raise ValueError(f"Could not read image: {image_path}")

    if len(img.shape) == 2 or (len(img.shape) == 3 and img.shape[2] == 1):
        # Grayscale image
        img = pad_image_to_multiple(img, patch_size=patch_size, is_color=False)
        features = []
        for y in range(0, img.shape[0], patch_size):
            for x in range(0, img.shape[1], patch_size):
                patch = img[y:y + patch_size, x:x + patch_size]
                features.append(extract_grayscale_histogram(patch))
        return np.stack(features)
    else:
        # Color image
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = pad_image_to_multiple(img, patch_size=patch_size, is_color=True)
        features = []
        for y in range(0, img.shape[0], patch_size):
            for x in range(0, img.shape[1], patch_size):
                patch = img[y:y + patch_size, x:x + patch_size]
                features.append(extract_color_histogram(patch))
        return np.stack(features)

# %%
def process_dataset(input_dir, patch_size=32):
    class_names = os.listdir(input_dir)
    for class_name in class_names:
        class_path = os.path.join(input_dir, class_name)
        processed_folder = os.path.join(class_path,"processed")
        os.makedirs(processed_folder,exist_ok=True)
        
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path,image_name)
            if(os.path.isfile(image_path)):
                features = process_image(image_path, patch_size)
                output_file = os.path.join(processed_folder,os.path.splitext(image_name)[0]+".npy")
                np.save(output_file,features)
                print(f"Processed : {output_file}")
    
process_dataset(r"../Group04-SUN397/group04/train/")
# Out:
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_aaepnczurcpxcpgk.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_acpggluskildlivv.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_acvolvfbonmmvewo.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_ajbuwfqzqpcursof.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_akypvrysfcrbtaeu.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_arcajpcsxcgmnmkb.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_axlbraofdeijprwh.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_ayfxrgkfvqdtwwvm.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_backlwgvjateapur.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bbokfmmphonmpkxr.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bbsiueaukmgjvwgs.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bcgjqcaiyxsrqfse.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bciseijixefzltcf.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bdjlnoifdoiquvrh.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bdshpmoxkctjmhpw.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bdvtphpofbfzubog.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bevanxtujzjwtkni.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bfngpvkuszarnysm.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bgfgpsxrqkjlvkxv.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bgfppzzsvjduqzuz.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bhjisshwcbzqudia.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bhnenfrkfodhbkwp.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_biiirkvwoiogjwwb.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bisbcefeheabaphm.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bitfyavfglppzmqq.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_biwagscwelhozdwm.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bjjslwfcgppnqthh.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bkwxgpimtrbxslek.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_blgesddskghneaan.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_blmagiaswkvzlzlf.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_bmusrulfyqtvpkqr.npy
# Processed : ../Group04-SUN397/group04/train/atrium_public\processed\sun_
npy
# Processed : ../Group04-SUN397/group04/test/general_store_outdoor\processed\sun_bxlbxustiovyqyrg.npy
# Processed : ../Group04-SUN397/group04/test/general_store_outdoor\processed\sun_bykwcbudkboacwpu.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aaobhuhwlnhrqjik.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_abfniidbbixmjfpz.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_abocynwezcjtoeoz.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_abuncxbmomelaoqh.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_abzhewxhkupqglrp.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_acfyfopypjafujea.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aconovecchdiyhmn.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_actisxsfbdhformb.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aeeedbcftiudasnk.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aepjmmsymjuekcfe.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_afggroduiyswtrkt.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aggcvywwsagakxdv.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aggmlhoxghgadtpb.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_agkuqmolwfhlnbaf.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_agtwzriaocvyvlsj.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_ahehvpocddpkbyfk.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_ailuximuubnoiiex.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_ajcunjqzpfesxmml.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_akpdkfnlumxjmzem.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aladrsefyjikdlzc.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_alshbczprerqckwa.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_amjpyvouwwbvlcxl.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_amwehwrtsibhdyhq.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_anbfwbtckbefitdh.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_anfycajcvkqlvaxv.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aniaozbprulflvap.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_anvdafhfaznqzxyk.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_apaxpxcjtsfzkald.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aqqmopmwfvugvuou.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aqvhzhlcwklicdqi.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aqytsscsytjmvadr.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_arandcitjfgdelqd.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_asbdixxvhttbmdzm.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_asvobgfaszemqkwl.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_asxhmsoprsrkdzjf.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_atnrunbrojcitcpd.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_auhfdptinwvxpylz.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_aulkwaybhitbvslu.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_avkazrfrakvznviz.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_awbhgsueflbypcsy.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_awqsozjsppomvmek.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_axaqmapdmxyoochs.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_axhecmrsunpmzknj.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_axtmbyyxfrlqqysg.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_axuwxmjppvzqpxxe.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_ayjsfmvaochgwesw.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_ayocuerhvyvuilzo.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_azbgcnphxslnxyyu.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_blyavozlvjyedkan.npy
# Processed : ../Group04-SUN397/group04/test/observatory_outdoor\processed\sun_bztinnbpwuvzrrmn.npy

# %%
def extract_mean_std_features(image_path, patch_size=7,step=1):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Could not read image: {image_path}")
    h, w = img.shape
    features = []
    
    for y in range(0, h - patch_size + 1, step):
        for x in range(0, w - patch_size + 1, step):
            patch = img[y:y+patch_size, x:x+patch_size]
            mean_val = np.mean(patch)
            std_val = np.std(patch)
            features.append([mean_val, std_val])

    return np.array(features)

# %%
def process_dataset(input_dir, patch_size=7, step=1):
    processed_folder=os.path.join(input_dir,"processed")
    os.makedirs(processed_folder,exist_ok=True)
    for image_name in os.listdir(input_dir):
        image_path = os.path.join(input_dir,image_name)
        if(os.path.isfile(image_path)):
            features = extract_mean_std_features(image_path, patch_size, step)
            output_file = os.path.join(processed_folder, os.path.splitext(image_name)[0] + ".npy")
            np.save(output_file,features)
            print(f"Processed: {output_file}")

process_dataset(r"../Group04-cervical_cytology_images/group04/Train/")
# Out:
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\106.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\107.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\108.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\109.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\110.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\111.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\112.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\113.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\114.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\115.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\116.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\117.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\118.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\119.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\120.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\121.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\122.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\123.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\124.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\125.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\126.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\127.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\128.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\129.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\130.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\131.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\132.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\133.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\34.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\35.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\36.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\37.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\38.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\39.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\40.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\41.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\42.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\43.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\44.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\45.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\61.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\62.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\63.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\64.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\65.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\66.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\67.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\68.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\69.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\70.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\71.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\72.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\73.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\74.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\75.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\76.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\77.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\78.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\89.npy
# Processed: ../Group04-cervical_cytology_images/group04/Train/processed\90.npy

# %%
process_dataset(r"../Group04-cervical_cytology_images/group04/Test/")
# Out:
# Processed: ../Group04-cervical_cytology_images/group04/Test/processed\14.npy
# Processed: ../Group04-cervical_cytology_images/group04/Test/processed\49.npy
# Processed: ../Group04-cervical_cytology_images/group04/Test/processed\54.npy
